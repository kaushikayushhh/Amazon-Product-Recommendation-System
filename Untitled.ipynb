# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("products.csv", encoding="latin1", on_bad_lines='skip')

# %%
df.head(1)
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Sion Softside Expandable Roller Luggage, Black...
#
#                                               imgurl  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
#
#                              producturl  stars   price   id
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5  139.99  104

# %%
df.shape
# Out:
# (598289, 7)

# %%
df = df.drop(df.index[5000:])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (5000, 7)

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
print(df.columns.tolist())
# Out:
# ['title', 'imgurl', 'producturl', 'stars', 'price', 'id']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       5000 non-null   object
#  1   imgurl      5000 non-null   object
#  2   producturl  5000 non-null   object
#  3   stars       5000 non-null   float64
#  4   price       5000 non-null   float64
#  5   id          5000 non-null   int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 234.5+ KB

# %%
df=pd.to_csv("new_products.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df=pd.to_csv("new_products.csv")
#
# AttributeError: module 'pandas' has no attribute 'to_csv'
